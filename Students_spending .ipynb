# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_stud_spending = pd.read_csv('student_spending.csv')

# %%
df_stud_spending
# Out:
#      Unnamed: 0  age      gender year_in_school             major  \
# 0             0   19  Non-binary       Freshman        Psychology
# 1             1   24      Female         Junior         Economics
# 2             2   24  Non-binary         Junior         Economics
# 3             3   23      Female         Senior  Computer Science
# 4             4   20      Female         Senior  Computer Science
# ..          ...  ...         ...            ...               ...
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0               958            270     5939      709   296             123
# ...

# %%
#remove the unnamed column
del df_stud_spending['Unnamed: 0']

# %%
df_stud_spending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1000 non-null   int64
#  1   gender                    1000 non-null   object
#  2   year_in_school            1000 non-null   object
#  3   major                     1000 non-null   object
#  4   monthly_income            1000 non-null   int64
#  5   financial_aid             1000 non-null   int64
#  6   tuition                   1000 non-null   int64
#  7   housing                   1000 non-null   int64
#  8   food                      1000 non-null   int64
#  9   transportation            1000 non-null   int64
#  10  books_supplies            1000 non-null   int64
#  11  entertainment             1000 non-null   int64
#  12  personal_care             1000 non-null   int64
#  13  technology                1000 non-null   int64
# ...

# %%
# Create a new dataframe focused on only the columns to be used for this descriptive analysis
# Retain on ['monthly_income','preferred_payment_method','age','personal_care','year_in_school','technology', 'gender']
df_new = df_stud_spending[['monthly_income','preferred_payment_method','age','personal_care','year_in_school','technology', 'gender']].copy()

# %%
df_new
# Out:
#      monthly_income preferred_payment_method  age  personal_care  \
# 0               958        Credit/Debit Card   19             78
# 1              1006        Credit/Debit Card   24             92
# 2               734                     Cash   24             23
# 3               617       Mobile Payment App   23             30
# 4               810        Credit/Debit Card   20             71
# ..              ...                      ...  ...            ...
# 995            1346                     Cash   22             38
# 996            1407       Mobile Payment App   19             98
# 997             957       Mobile Payment App   20             46
# 998            1174       Mobile Payment App   22             90
# 999             541                     Cash   24             43
#
#     year_in_school  technology      gender
# 0         Freshman         134  Non-binary
# 1           Junior         226      Female
# 2           Junior         239  Non-binary
# ...

# %%
df_new.head(20)
# Out:
#     monthly_income preferred_payment_method  age  personal_care  \
# 0              958        Credit/Debit Card   19             78
# 1             1006        Credit/Debit Card   24             92
# 2              734                     Cash   24             23
# 3              617       Mobile Payment App   23             30
# 4              810        Credit/Debit Card   20             71
# 5              523       Mobile Payment App   25             38
# 6             1354        Credit/Debit Card   23             38
# 7              631       Mobile Payment App   23             90
# 8             1402        Credit/Debit Card   22             41
# 9             1423       Mobile Payment App   18             74
# 10             762        Credit/Debit Card   23             21
# 11            1068        Credit/Debit Card   25             57
# 12             719        Credit/Debit Card   21             50
# 13            1176       Mobile Payment App   19             77
# ...

# %%
df_new.tail(20)
# Out:
#      monthly_income preferred_payment_method  age  personal_care  \
# 980            1019       Mobile Payment App   18             92
# 981             669        Credit/Debit Card   24             27
# 982             933       Mobile Payment App   19             82
# 983            1166                     Cash   20             56
# 984            1197       Mobile Payment App   25             58
# 985             973                     Cash   19             70
# 986            1381                     Cash   23             83
# 987            1082        Credit/Debit Card   22             21
# 988            1160                     Cash   23             64
# 989            1011                     Cash   22             73
# 990            1412       Mobile Payment App   20             41
# 991            1391                     Cash   24             66
# 992            1293        Credit/Debit Card   20             64
# ...

# %%
df_new.isnull().sum()
# Out:
# monthly_income              0
# preferred_payment_method    0
# age                         0
# personal_care               0
# year_in_school              0
# technology                  0
# gender                      0
# dtype: int64

# %%
df_new.describe()
# Out:
#        monthly_income          age  personal_care   technology
# count     1000.000000  1000.000000    1000.000000  1000.000000
# mean      1020.650000    21.675000      60.699000   178.304000
# std        293.841161     2.322664      22.898007    71.744441
# min        501.000000    18.000000      20.000000    50.000000
# 25%        770.750000    20.000000      41.000000   114.000000
# 50%       1021.000000    22.000000      62.000000   178.000000
# 75%       1288.250000    24.000000      80.000000   241.000000
# max       1500.000000    25.000000     100.000000   300.000000

# %%
df_new['monthly_income'].describe()
# Out:
# count    1000.000000
# mean     1020.650000
# std       293.841161
# min       501.000000
# 25%       770.750000
# 50%      1021.000000
# 75%      1288.250000
# max      1500.000000
# Name: monthly_income, dtype: float64

# %%
#Analyse data using Correlation
corr_matrix = df_new[['age','gender','year_in_school','personal_care','technology','preferred_payment_method','monthly_income']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#Visualise distribution of preferred payment method
sns.set(style="whitegrid")
plt.figure(figsize=(6, 6))
ax = sns.countplot(x='preferred_payment_method', data=df_new, palette='muted')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')


plt.title('Distribution of Preferred Payment Method')
plt.show()

# %%
sns.set(style="darkgrid")

# Create a pie chart for 'technology'
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(df_new['age'].value_counts(), labels=df_new['age'].value_counts().index, autopct='%1.2f%%', colors=sns.color_palette('pastel'), startangle=90)

# Set plot title
ax.set_title('Distribution of Students Spending by Age')

# Display the plot
plt.show()

# %%
#Using Kdeplot to provide insights into the distribution of students income.
sns.kdeplot(df_new['monthly_income'], shade=True)
plt.title('Density plot of students monthly_income')
plt.xlabel('monthly_income')
plt.ylabel('Density')
plt.show()

# %%
sns.set(style="darkgrid")

# Create a pie chart for 'technology'
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(df_new['gender'].value_counts(), labels=df_new['gender'].value_counts().index, autopct='%1.2f%%', colors=sns.color_palette('pastel'), startangle=90)

# Set plot title
ax.set_title('Distribution of Students Spending by Gender')

# Display the plot
plt.show()

# %%
sns.barplot(x=df_new['year_in_school'], y=df_new['technology'])
plt.xlabel('year_in_school')
plt.ylabel('technology')
plt.show()

# %%
sns.kdeplot(df_new['personal_care'], shade=True)
plt.title('Density plot of students spending on personal_care')
plt.xlabel('personal_care')
plt.ylabel('Density')
plt.show()
